# %% [markdown]
# <a href="https://colab.research.google.com/github/HugocamposL3/Linguagem-Python-Para-Data-Science/blob/main/Detector_Facial_rev1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Importando Bibliotecas Necessárias

# %%
import cv2
from matplotlib import pyplot as plt

# %% [markdown]
# ## Carregando Arquivo XML

# %%
carregaAlgoritmo = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %% [markdown]
# ##Carregando a Imagem

# %%
imagem = cv2.imread('/content/sample_data/imagens/images7.jpg')

# %% [markdown]
# ##Plotando a Imagem Usando MatplotLib

# %%
plt.imshow(imagem) # A imagem sai no modo BGR

# %% [markdown]
# ##Transformando a Imagem em Modo RGB

# %%
image_rgb = cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB)

# %%
plt.figure()
plt.imshow(image_rgb)
plt.show()

# %% [markdown]
# ##Transformando a Imagem tom de Cinza porque a Acurácia é melhor

# %%
imagemCinza = cv2.cvtColor(imagem, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(imagemCinza)

# %% [markdown]
# ## Comando Para Detecção de Faces

# %%
faces = carregaAlgoritmo.detectMultiScale(image_rgb)
print(faces)
# Out:
# [[ 77  23  28  28]
#  [ 39  34  25  25]
#  [166  47  25  25]]

# %%
for(x, y, l, a) in faces:
    cv2.rectangle(image_rgb, (x, y), (x + l, y + a), (0, 255, 0), 2) # imagem , (ponto inicial & ponto final),

# %%
plt.imshow(image_rgb)
plt.show()

# %%
cv2.imwrite('familia3.jpg',image_rgb)
# Out:
# True

# %% [markdown]
# ##Referência: Código Retirado do Canal C&S Analytics
# ##Link: https://www.youtube.com/watch?v=F7uw3oPC1wQ
