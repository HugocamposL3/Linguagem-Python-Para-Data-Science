# %% [markdown]
# #Aula 1 - Linguagem de Programação Python

# %%
print ('Hello World') # Exibir o Hello World 
print ('Sejam Bem vindos') # Exibir boas vindas
# Out:
# Helloo World
# Sejam Bem vindos

# %%
print ('Olá, tudo bem?')
print(input()) # Para que o usuario responda algo
# Out:
# Olá, tudo bem?
# Sim
# Sim

# %%
input ('Colocar valor: ')
# Out:
# Colocar valor: 15
# '15'

# %%
2**2
# Out:
# 4

# %%
valor_1 = int(input('Insira um valor: '))
valor_2 = int(input('Insira o segundo valor: '))
print ('O valor 1 Inserido é igual a {} e o valor 2 é igual a {}.'.format(valor_1,valor_2))
# Out:
# Insira um valor: 5
# Insira o segundo valor: 4
# O valor 1 Inserido é igual a 5 e o valor 2 é igual a 4.

# %%
soma = valor_1 + valor_2
subtração = valor_1 - valor_2
multiplicação = valor_1 * valor_2
divisão = valor_1/valor_2
print ('A soma dos valores é: {}'.format(soma)) 
print ('A multiplicação dos valores é: {} \nA divisão dos valores é:{}'.format(multiplicação,divisão))
# Out:
# A soma dos valores é: 9
# A multiplicação dos valores é: 20
# A divisão dos valores é:1.25
