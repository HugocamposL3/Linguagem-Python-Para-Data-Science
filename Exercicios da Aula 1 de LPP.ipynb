# %% [markdown]
# #Desafio do Dolar da ONG

# %%
#Exercicio de fixação 1 - Resolução 1 
valor_dolar = float(input('Insira um valor em dolar: '))
valor_real = valor_dolar * 5
print ('O valor em real é equivalente: {}'.format(valor_real))
# Out:
# Insira um valor em dolar: 4
# O valor em real é equivalente: 20.0

# %%
#Exercicio de fixação 1 - Resolução 2
valor_dolar = float(input('Insira um valor em dolar: '))
print ('O valor em real é equivalente: {}'.format(valor_dolar * 5))
# Out:
# Insira um valor em dolar: 5
# O valor em real é equivalente: 25.0

# %%
#Exercicio de fixação 1 - Resolução 3
valor_dolar = float(input('Insira um valor em dolar: '))
cotação = float(input('Insira o valor respectivo da cotação:'))
print ('O valor em real é equivalente: {}'.format(valor_dolar * cotação))

# %% [markdown]
# ##Desafio do Mercado Municipal com o Carro

# %%
#Exercicio de fixação 2 - Resolução 1 
valor_kminicial = float(input('Insira o valor da Km Inicial: '))
valor_kmfinalal = float(input('Insira o valor da Km Final: '))
valor_ltabaste = float(input('Insira o valor de litros abastecidos: '))
print ('O valor da média: {}'.format((valor_kmfinalal - valor_kminicial)/valor_ltabaste))
